# %%
# from client import MLModelClient
from comp import MLModelClient

# %%
client = MLModelClient('142.1.46.240', 50051)

# %%
embedding = client.embed_sentence("hello")
embedding
# Out:
# [-0.032012939453125, 0.0232391357421875, -0.041656494140625, 0.006671905517578125, -0.02740478515625, -0.03289794921875, -0.03045654296875, -0.03326416015625, 0.0004210472106933594, 0.007793426513671875, -0.0004475116729736328, 0.010772705078125, 0.0164337158203125, -0.0126800537109375, 0.00977325439453125, -0.02581787109375, 0.026763916015625, -0.023529052734375, 0.0009198188781738281, -0.033660888671875, -0.051605224609375, -0.0150604248046875, 0.01055908203125, -0.00688934326171875, 0.0197906494140625, 0.03717041015625, -0.038055419921875, 0.0045623779296875, 0.0011034011840820312, -0.024200439453125, 0.048248291015625, 0.0728759765625, -0.01035308837890625, -0.045379638671875, -0.028289794921875, -0.04736328125, 0.0111083984375, -0.011688232421875, -0.058197021484375, 0.0210113525390625, 0.01473236083984375, 0.02099609375, 0.00934600830078125, -0.04656982421875, 0.02178955078125, -0.0498046875, -0.0288848876953125, -7.289648056030273e-05, 0.022705078125, -0.05291748046875, 0.0218
# ...

# %%
query = "Organic skincare products for sensitive skin"
documents = [
    "Organic skincare for sensitive skin with aloe vera and chamomile.",
    "New makeup trends focus on bold colors and innovative techniques",
    "Bio-Hautpflege für empfindliche Haut mit Aloe Vera und Kamille",
    "Neue Make-up-Trends setzen auf kräftige Farben und innovative Techniken",
    "Cuidado de la piel orgánico para piel sensible con aloe vera y manzanilla",
    "Las nuevas tendencias de maquillaje se centran en colores vivos y técnicas innovadoras",
    "针对敏感肌专门设计的天然有机护肤产品",
    "新的化妆趋势注重鲜艳的颜色和创新的技巧",
    "敏感肌のために特別に設計された天然有機スキンケア製品",
    "新しいメイクのトレンドは鮮やかな色と革新的な技術に焦点を当てています",
]
# reranked_docs = client.rerank_documents(documents, query)
# reranked_docs

# %%
embeddings = client.embed_batch(documents)
len(embeddings) == len(documents)
# Out:
# True

# %%
compressed_prompt = client.compress_prompt(query, documents)
compressed_prompt
# Out:
# 'aloe chamomile\n\ntrends techniques\n\n-Hautpflege Aloe Kamille\n\nMake-up Farben Techniken\n\naloe vera manzanilla\n\ntendencias técnicas innovadoras\n\n'

# %%
rewritten_prompt = client.rewrite_prompt(query)
rewritten_prompt
# Out:
# 'Organic skincare products for sensitive skin have become increasingly popular in recent years, driven by concerns over the environmental impact of conventional chemical ingredients and the desire to create products that are safe and effective for individuals with sensitive skin types. However, the scientific community is still grappling with the long-term effects of these products on the skin, particularly on the skin’s barrier function. As a result, the industry is actively seeking ways to improve the safety and efficacy of these products, while also addressing the need for sustainable production of ingredients. This article will explore the current research, challenges, and future prospects of organic skincare products for sensitive skin, while emphasizing the importance of the science behind the science.\n**Introduction**\nThe rise of organic skincare products has sparked a trend in the skincare industry, driven by concerns over the environmental impact of conventional chemical i
# ...

# %%
from openai import OpenAI
OpenAI.api_key = "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"
client = OpenAI(api_key="ollama", base_url="http://localhost:11434/v1")
embeddings = client.embeddings.create(
    input=query,
    model="embeddinggemma:latest"
)
embeddings
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[-0.15517747, 0.009655605, 0.022243986, -0.0019269158, 0.015716229, 0.025887221, -0.068421565, 0.053968415, 0.039721243, -0.051862705, -0.01540223, -0.023353534, 0.017226245, -0.028649747, 0.08579813, -0.007960369, 0.025096258, -0.030330207, -0.037165917, 0.008453217, 0.020214513, -0.021711983, -0.010889589, -0.013539735, -0.013344851, 0.039581217, 0.009629461, -0.0054646237, -0.01064179, -0.034029696, 0.04495546, 0.025882177, 0.028992582, 0.026833583, 0.002779012, 0.05947844, 0.049185388, -0.071683004, 0.06922889, -0.016429747, -0.08431479, 0.056199357, -0.013895152, -0.03650575, 0.035302147, -0.017900227, -0.05829718, -0.051055983, -0.027959995, 0.022850139, -0.023545615, 0.0073853848, -0.028173743, 0.017306613, -0.041436978, -0.04085862, -0.012650526, 0.0069116433, -0.020572376, 0.044947583, -0.07211287, -0.04833402, -0.022482583, 0.012484812, 0.037981752, -0.04129881, -0.023158437, 0.037196275, 0.011009196, 0.26388794, -0.02470360
# ...

# %%
for embedding in embeddings.data:
    print(embedding.embedding)
# Out:
# [-0.1132551, -0.00012657324, 0.0072408156, 0.0070348945, 0.00075909606, 0.02487064, -0.08340556, 0.05907056, 0.03199838, -0.049363602, -0.0075118546, -0.025680274, 0.013848018, -0.002708428, 0.07530022, -0.017671611, -0.03269701, -0.00877544, -0.08100203, 0.0048558637, 0.014424484, -0.013976713, 0.005113876, 0.0005026978, 0.0088880835, 0.048550375, 0.010371953, -0.020166634, -0.015129589, -0.037866216, 0.043911204, 0.010446411, 0.0064403345, 0.05229371, 0.015271372, 0.042203143, 0.0069165807, -0.052553527, 0.068866804, -0.023466922, -0.09446929, 0.05034846, -0.003896399, -0.045249492, 0.020387197, -0.025622541, -0.059466932, -0.031631656, -0.033895634, 0.049777873, -0.0480309, 0.03317718, -0.024246244, 0.023275772, -0.022792451, -0.04961972, 0.029889291, 0.021644002, -0.011682948, 0.029983371, -0.08403757, -0.047533043, -0.049949676, 0.02212543, 0.0033370592, -0.043298416, 0.011816257, 0.0580562, 0.023371005, 0.2442556, 0.0027158435, -0.038230658, -0.014837074, -0.08031336, 0.2375217
# ...
